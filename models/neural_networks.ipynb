# %%
import pandas as pd
from PIL import Image
import os
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import time
start_time = time.time()

# %%
images_path = '../images'
population_data_path = '../data/full_data.csv'

# %%
def crop_and_resize(image: Image.Image, size: int) -> Image.Image:
    """
    Crop a PIL image to a square by trimming the longer side and centering,
    then resize it to the designated resolution.
    
    :param image: Input PIL Image
    :param size: Target resolution (size x size)
    :return: Processed PIL Image
    """
    width, height = image.size
    min_side = min(width, height)
    
    # Calculate crop box for center cropping
    left = (width - min_side) // 2
    top = (height - min_side) // 2
    right = left + min_side
    bottom = top + min_side
    
    # Crop to square
    cropped_image = image.crop((left, top, right, bottom))
    
    # Resize to designated resolution
    resized_image = cropped_image.resize((size, size), Image.LANCZOS)
    
    return resized_image

# %%
images = {}

for dir in os.listdir(images_path)[:]:
    if not dir.endswith('.png'):
        continue
    
    full_path = f'{images_path}/{dir}'
    image = Image.open(full_path)
    square_image = crop_and_resize(image, 128)
    images[dir[:-4].lower()] = square_image
    
print(f'Loaded {len(images)} images')
images
# Out:
# Loaded 944 images
# {'rio_de_janeiro': <PIL.Image.Image image mode=RGB size=128x128>,
#  'sao_luis': <PIL.Image.Image image mode=RGB size=128x128>,
#  'arequipa': <PIL.Image.Image image mode=RGB size=128x128>,
#  'posadas': <PIL.Image.Image image mode=RGB size=128x128>,
#  'zaragoza': <PIL.Image.Image image mode=RGB size=128x128>,
#  "xi'an": <PIL.Image.Image image mode=RGB size=128x128>,
#  'hrodna': <PIL.Image.Image image mode=RGB size=128x128>,
#  'guadalajara': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bogor': <PIL.Image.Image image mode=RGB size=128x128>,
#  'tegucigalpa': <PIL.Image.Image image mode=RGB size=128x128>,
#  'siem_reap': <PIL.Image.Image image mode=RGB size=128x128>,
#  'weinan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'al_hasakah': <PIL.Image.Image image mode=RGB size=128x128>,
#  'stockholm': <PIL.Image.Image image mode=RGB size=128x128>,
#  'quito': <PIL.Image.Image image mode=RGB size=128x128>,
#  'surat': <PIL.Image.Image image mode=RGB size=128x128>,
#  'madrid': <PIL.Image.Image image mode=RGB size=128x128>,
#  'culiacan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'panihati': <PIL.Image.Image image mode=RGB size=128x128>,
#  'quebec_city': <PIL.Image.Image image mode=RGB size=128x128>,
#  'nanchong': <PIL.Image.Image image mode=RGB size=128x128>,
#  'iasi': <PIL.Image.Image image mode=RGB size=128x128>,
#  'lambarene': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bhatpara': <PIL.Image.Image image mode=RGB size=128x128>,
#  'manta': <PIL.Image.Image image mode=RGB size=128x128>,
#  'herat': <PIL.Image.Image image mode=RGB size=128x128>,
#  'nawabshah': <PIL.Image.Image image mode=RGB size=128x128>,
#  'rajahmundry': <PIL.Image.Image image mode=RGB size=128x128>,
#  'sao_paulo': <PIL.Image.Image image mode=RGB size=128x128>,
#  'takeo': <PIL.Image.Image image mode=RGB size=128x128>,
#  'basel': <PIL.Image.Image image mode=RGB size=128x128>,
#  'galway': <PIL.Image.Image image mode=RGB size=128x128>,
#  'jiujiang': <PIL.Image.Image image mode=RGB size=128x128>,
#  'mexicali': <PIL.Image.Image image mode=RGB size=128x128>,
#  'lyon': <PIL.Image.Image image mode=RGB size=128x128>,
#  'marikina_city': <PIL.Image.Image image mode=RGB size=128x128>,
#  'ujjain': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kobe': <PIL.Image.Image image mode=RGB size=128x128>,
#  'xam_nua': <PIL.Image.Image image mode=RGB size=128x128>,
#  'chandigarh': <PIL.Image.Image image mode=RGB size=128x128>,
#  'monywa': <PIL.Image.Image image mode=RGB size=128x128>,
#  'split': <PIL.Image.Image image mode=RGB size=128x128>,
#  'srinagar': <PIL.Image.Image image mode=RGB size=128x128>,
#  'heze': <PIL.Image.Image image mode=RGB size=128x128>,
#  'adana': <PIL.Image.Image image mode=RGB size=128x128>,
#  'medan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'orebro': <PIL.Image.Image image mode=RGB size=128x128>,
#  'haiphong': <PIL.Image.Image image mode=RGB size=128x128>,
#  'krasnodar': <PIL.Image.Image image mode=RGB size=128x128>,
#  'sacaba': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kraljevo': <PIL.Image.Image image mode=RGB size=128x128>,
#  'tromso': <PIL.Image.Image image mode=RGB size=128x128>,
#  'turkmenbasy': <PIL.Image.Image image mode=RGB size=128x128>,
#  'yinchuan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'the_hague': <PIL.Image.Image image mode=RGB size=128x128>,
#  'machala': <PIL.Image.Image image mode=RGB size=128x128>,
#  'los_angeles': <PIL.Image.Image image mode=RGB size=128x128>,
#  'udaipur': <PIL.Image.Image image mode=RGB size=128x128>,
#  'lerik': <PIL.Image.Image image mode=RGB size=128x128>,
#  'santa_tecla': <PIL.Image.Image image mode=RGB size=128x128>,
#  'asansol': <PIL.Image.Image image mode=RGB size=128x128>,
#  'meishan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kharkiv': <PIL.Image.Image image mode=RGB size=128x128>,
#  'belgrade': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bucaramanga': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bien_hoa': <PIL.Image.Image image mode=RGB size=128x128>,
#  'vientiane': <PIL.Image.Image image mode=RGB size=128x128>,
#  'shangrao': <PIL.Image.Image image mode=RGB size=128x128>,
#  'urumqi': <PIL.Image.Image image mode=RGB size=128x128>,
#  'maoming': <PIL.Image.Image image mode=RGB size=128x128>,
#  'osijek': <PIL.Image.Image image mode=RGB size=128x128>,
#  'manila': <PIL.Image.Image image mode=RGB size=128x128>,
#  'rawalpindi': <PIL.Image.Image image mode=RGB size=128x128>,
#  'porto_alegre': <PIL.Image.Image image mode=RGB size=128x128>,
#  'jammu': <PIL.Image.Image image mode=RGB size=128x128>,
#  'odense': <PIL.Image.Image image mode=RGB size=128x128>,
#  'valenzuela': <PIL.Image.Image image mode=RGB size=128x128>,
#  'gyor': <PIL.Image.Image image mode=RGB size=128x128>,
#  'joao_pessoa': <PIL.Image.Image image mode=RGB size=128x128>,
#  'shangqiu': <PIL.Image.Image image mode=RGB size=128x128>,
#  'ibb': <PIL.Image.Image image mode=RGB size=128x128>,
#  'chinandega': <PIL.Image.Image image mode=RGB size=128x128>,
#  'narsingdi': <PIL.Image.Image image mode=RGB size=128x128>,
#  'zhuhai': <PIL.Image.Image image mode=RGB size=128x128>,
#  'pontianak': <PIL.Image.Image image mode=RGB size=128x128>,
#  'gaziantep': <PIL.Image.Image image mode=RGB size=128x128>,
#  'loja': <PIL.Image.Image image mode=RGB size=128x128>,
#  'namur': <PIL.Image.Image image mode=RGB size=128x128>,
#  'comayagua': <PIL.Image.Image image mode=RGB size=128x128>,
#  'thakhek': <PIL.Image.Image image mode=RGB size=128x128>,
#  'foshan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'glasgow': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bikaner': <PIL.Image.Image image mode=RGB size=128x128>,
#  'schaarbeek': <PIL.Image.Image image mode=RGB size=128x128>,
#  'mashhad': <PIL.Image.Image image mode=RGB size=128x128>,
#  'indore': <PIL.Image.Image image mode=RGB size=128x128>,
#  'latur': <PIL.Image.Image image mode=RGB size=128x128>,
#  'san_pedro_de_macoris': <PIL.Image.Image image mode=RGB size=128x128>,
#  'warangal': <PIL.Image.Image image mode=RGB size=128x128>,
#  'craiova': <PIL.Image.Image image mode=RGB size=128x128>,
#  'dongguan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kragujevac': <PIL.Image.Image image mode=RGB size=128x128>,
#  'london': <PIL.Image.Image image mode=RGB size=128x128>,
#  'changwon': <PIL.Image.Image image mode=RGB size=128x128>,
#  'minsk': <PIL.Image.Image image mode=RGB size=128x128>,
#  'ghent': <PIL.Image.Image image mode=RGB size=128x128>,
#  'malegaon': <PIL.Image.Image image mode=RGB size=128x128>,
#  'merida': <PIL.Image.Image image mode=RGB size=128x128>,
#  'thessaloniki': <PIL.Image.Image image mode=RGB size=128x128>,
#  'havana': <PIL.Image.Image image mode=RGB size=128x128>,
#  'la_ceiba': <PIL.Image.Image image mode=RGB size=128x128>,
#  'gujranwala': <PIL.Image.Image image mode=RGB size=128x128>,
#  'peristeri': <PIL.Image.Image image mode=RGB size=128x128>,
#  'omsk': <PIL.Image.Image image mode=RGB size=128x128>,
#  'qingdao': <PIL.Image.Image image mode=RGB size=128x128>,
#  'limerick': <PIL.Image.Image image mode=RGB size=128x128>,
#  'portoviejo': <PIL.Image.Image image mode=RGB size=128x128>,
#  'talcahuano': <PIL.Image.Image image mode=RGB size=128x128>,
#  'beirut': <PIL.Image.Image image mode=RGB size=128x128>,
#  'qarshi': <PIL.Image.Image image mode=RGB size=128x128>,
#  'curitiba': <PIL.Image.Image image mode=RGB size=128x128>,
#  'ciudad_bolivar': <PIL.Image.Image image mode=RGB size=128x128>,
#  'katowice': <PIL.Image.Image image mode=RGB size=128x128>,
#  'ibague': <PIL.Image.Image image mode=RGB size=128x128>,
#  'dhamar': <PIL.Image.Image image mode=RGB size=128x128>,
#  'ciudad_choluteca': <PIL.Image.Image image mode=RGB size=128x128>,
#  'campo_grande': <PIL.Image.Image image mode=RGB size=128x128>,
#  'dhangadhi': <PIL.Image.Image image mode=RGB size=128x128>,
#  'neijiang': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kolhapur': <PIL.Image.Image image mode=RGB size=128x128>,
#  'hsinchu': <PIL.Image.Image image mode=RGB size=128x128>,
#  'santiago_de_cuba': <PIL.Image.Image image mode=RGB size=128x128>,
#  'san_pedro_sula': <PIL.Image.Image image mode=RGB size=128x128>,
#  'washington': <PIL.Image.Image image mode=RGB size=128x128>,
#  'shekhupura': <PIL.Image.Image image mode=RGB size=128x128>,
#  'mandalay': <PIL.Image.Image image mode=RGB size=128x128>,
#  "ha'il": <PIL.Image.Image image mode=RGB size=128x128>,
#  'setubal': <PIL.Image.Image image mode=RGB size=128x128>,
#  'lausanne': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kunduz': <PIL.Image.Image image mode=RGB size=128x128>,
#  'huaibei': <PIL.Image.Image image mode=RGB size=128x128>,
#  'holon': <PIL.Image.Image image mode=RGB size=128x128>,
#  'hefei': <PIL.Image.Image image mode=RGB size=128x128>,
#  'moradabad': <PIL.Image.Image image mode=RGB size=128x128>,
#  'san_francisco_de_macoris': <PIL.Image.Image image mode=RGB size=128x128>,
#  'liberec': <PIL.Image.Image image mode=RGB size=128x128>,
#  'zhengzhou': <PIL.Image.Image image mode=RGB size=128x128>,
#  'sofia': <PIL.Image.Image image mode=RGB size=128x128>,
#  'santa_marta': <PIL.Image.Image image mode=RGB size=128x128>,
#  'konibodom': <PIL.Image.Image image mode=RGB size=128x128>,
#  'sanya': <PIL.Image.Image image mode=RGB size=128x128>,
#  'yantai': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kathmandu': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bhayandar': <PIL.Image.Image image mode=RGB size=128x128>,
#  'baku': <PIL.Image.Image image mode=RGB size=128x128>,
#  'pecs': <PIL.Image.Image image mode=RGB size=128x128>,
#  'seoul': <PIL.Image.Image image mode=RGB size=128x128>,
#  'liuzhou': <PIL.Image.Image image mode=RGB size=128x128>,
#  'jiaxing': <PIL.Image.Image image mode=RGB size=128x128>,
#  'nonthaburi': <PIL.Image.Image image mode=RGB size=128x128>,
#  'depok': <PIL.Image.Image image mode=RGB size=128x128>,
#  'nellore': <PIL.Image.Image image mode=RGB size=128x128>,
#  'lima': <PIL.Image.Image image mode=RGB size=128x128>,
#  'banska_bystrica': <PIL.Image.Image image mode=RGB size=128x128>,
#  'jamnagar': <PIL.Image.Image image mode=RGB size=128x128>,
#  'palembang': <PIL.Image.Image image mode=RGB size=128x128>,
#  'oulu': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kampong_cham': <PIL.Image.Image image mode=RGB size=128x128>,
#  'dushanbe': <PIL.Image.Image image mode=RGB size=128x128>,
#  'sheffield': <PIL.Image.Image image mode=RGB size=128x128>,
#  'pinsk': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kuala_lumpur': <PIL.Image.Image image mode=RGB size=128x128>,
#  'haifa': <PIL.Image.Image image mode=RGB size=128x128>,
#  'klang': <PIL.Image.Image image mode=RGB size=128x128>,
#  'yokohama': <PIL.Image.Image image mode=RGB size=128x128>,
#  'victoria': <PIL.Image.Image image mode=RGB size=128x128>,
#  'zahle': <PIL.Image.Image image mode=RGB size=128x128>,
#  'san_salvador': <PIL.Image.Image image mode=RGB size=128x128>,
#  'pyongyang': <PIL.Image.Image image mode=RGB size=128x128>,
#  'holguin': <PIL.Image.Image image mode=RGB size=128x128>,
#  'guayaquil': <PIL.Image.Image image mode=RGB size=128x128>,
#  'fukuoka': <PIL.Image.Image image mode=RGB size=128x128>,
#  'karaj': <PIL.Image.Image image mode=RGB size=128x128>,
#  'ambato': <PIL.Image.Image image mode=RGB size=128x128>,
#  'tursunzoda': <PIL.Image.Image image mode=RGB size=128x128>,
#  'riberalta': <PIL.Image.Image image mode=RGB size=128x128>,
#  'nanjing': <PIL.Image.Image image mode=RGB size=128x128>,
#  'ecatepec': <PIL.Image.Image image mode=RGB size=128x128>,
#  'baghlan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'chiclayo': <PIL.Image.Image image mode=RGB size=128x128>,
#  'konya': <PIL.Image.Image image mode=RGB size=128x128>,
#  'cusco': <PIL.Image.Image image mode=RGB size=128x128>,
#  'tbilisi': <PIL.Image.Image image mode=RGB size=128x128>,
#  'dhanbad': <PIL.Image.Image image mode=RGB size=128x128>,
#  'palma': <PIL.Image.Image image mode=RGB size=128x128>,
#  'liaocheng': <PIL.Image.Image image mode=RGB size=128x128>,
#  'aligarh': <PIL.Image.Image image mode=RGB size=128x128>,
#  'al_`aqabah': <PIL.Image.Image image mode=RGB size=128x128>,
#  'qujing': <PIL.Image.Image image mode=RGB size=128x128>,
#  'naryn': <PIL.Image.Image image mode=RGB size=128x128>,
#  'caracas': <PIL.Image.Image image mode=RGB size=128x128>,
#  'jalandhar': <PIL.Image.Image image mode=RGB size=128x128>,
#  'tolyatti': <PIL.Image.Image image mode=RGB size=128x128>,
#  '`ajman': <PIL.Image.Image image mode=RGB size=128x128>,
#  'durango': <PIL.Image.Image image mode=RGB size=128x128>,
#  'izhevsk': <PIL.Image.Image image mode=RGB size=128x128>,
#  'calgary': <PIL.Image.Image image mode=RGB size=128x128>,
#  'hangzhou': <PIL.Image.Image image mode=RGB size=128x128>,
#  'pak_kret': <PIL.Image.Image image mode=RGB size=128x128>,
#  'zilina': <PIL.Image.Image image mode=RGB size=128x128>,
#  'cagayan_de_oro': <PIL.Image.Image image mode=RGB size=128x128>,
#  'zurich': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bhiwandi': <PIL.Image.Image image mode=RGB size=128x128>,
#  'taraz': <PIL.Image.Image image mode=RGB size=128x128>,
#  'drogheda': <PIL.Image.Image image mode=RGB size=128x128>,
#  'tunis': <PIL.Image.Image image mode=RGB size=128x128>,
#  'dusseldorf': <PIL.Image.Image image mode=RGB size=128x128>,
#  'suzhou': <PIL.Image.Image image mode=RGB size=128x128>,
#  'south_boston': <PIL.Image.Image image mode=RGB size=128x128>,
#  'incheon': <PIL.Image.Image image mode=RGB size=128x128>,
#  'debrecen': <PIL.Image.Image image mode=RGB size=128x128>,
#  'rosario': <PIL.Image.Image image mode=RGB size=128x128>,
#  'zadar': <PIL.Image.Image image mode=RGB size=128x128>,
#  'temuco': <PIL.Image.Image image mode=RGB size=128x128>,
#  'durgapur': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kulob': <PIL.Image.Image image mode=RGB size=128x128>,
#  'tokmok': <PIL.Image.Image image mode=RGB size=128x128>,
#  'voronezh': <PIL.Image.Image image mode=RGB size=128x128>,
#  'sliven': <PIL.Image.Image image mode=RGB size=128x128>,
#  'phnom_penh': <PIL.Image.Image image mode=RGB size=128x128>,
#  'lublin': <PIL.Image.Image image mode=RGB size=128x128>,
#  'ufa': <PIL.Image.Image image mode=RGB size=128x128>,
#  'quetzaltenango': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bangkok': <PIL.Image.Image image mode=RGB size=128x128>,
#  'santiago': <PIL.Image.Image image mode=RGB size=128x128>,
#  'tianjin': <PIL.Image.Image image mode=RGB size=128x128>,
#  'savannakhet': <PIL.Image.Image image mode=RGB size=128x128>,
#  'guwahati': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bucharest': <PIL.Image.Image image mode=RGB size=128x128>,
#  'sidon': <PIL.Image.Image image mode=RGB size=128x128>,
#  'donetsk': <PIL.Image.Image image mode=RGB size=128x128>,
#  'munich': <PIL.Image.Image image mode=RGB size=128x128>,
#  'salt_lake_city': <PIL.Image.Image image mode=RGB size=128x128>,
#  'barranquilla': <PIL.Image.Image image mode=RGB size=128x128>,
#  'santa_fe': <PIL.Image.Image image mode=RGB size=128x128>,
#  'zhongshan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'larkana': <PIL.Image.Image image mode=RGB size=128x128>,
#  'naucalpan_de_juarez': <PIL.Image.Image image mode=RGB size=128x128>,
#  'sucre': <PIL.Image.Image image mode=RGB size=128x128>,
#  'campinas': <PIL.Image.Image image mode=RGB size=128x128>,
#  'baghdad': <PIL.Image.Image image mode=RGB size=128x128>,
#  'vienna': <PIL.Image.Image image mode=RGB size=128x128>,
#  'malang': <PIL.Image.Image image mode=RGB size=128x128>,
#  'budapest': <PIL.Image.Image image mode=RGB size=128x128>,
#  'hiroshima': <PIL.Image.Image image mode=RGB size=128x128>,
#  'guatemala_city': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kolkata': <PIL.Image.Image image mode=RGB size=128x128>,
#  'granada': <PIL.Image.Image image mode=RGB size=128x128>,
#  'taguig_city': <PIL.Image.Image image mode=RGB size=128x128>,
#  'zemun': <PIL.Image.Image image mode=RGB size=128x128>,
#  'fort_worth': <PIL.Image.Image image mode=RGB size=128x128>,
#  "at_ta'if": <PIL.Image.Image image mode=RGB size=128x128>,
#  'quetta': <PIL.Image.Image image mode=RGB size=128x128>,
#  'callao': <PIL.Image.Image image mode=RGB size=128x128>,
#  'multan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'indianapolis': <PIL.Image.Image image mode=RGB size=128x128>,
#  'san_martin': <PIL.Image.Image image mode=RGB size=128x128>,
#  'portland': <PIL.Image.Image image mode=RGB size=128x128>,
#  'changzhou': <PIL.Image.Image image mode=RGB size=128x128>,
#  'taichung': <PIL.Image.Image image mode=RGB size=128x128>,
#  'al_ahmadi': <PIL.Image.Image image mode=RGB size=128x128>,
#  'san_francisco': <PIL.Image.Image image mode=RGB size=128x128>,
#  'peshawar': <PIL.Image.Image image mode=RGB size=128x128>,
#  'makassar': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kahriz_sang': <PIL.Image.Image image mode=RGB size=128x128>,
#  'nanded': <PIL.Image.Image image mode=RGB size=128x128>,
#  'turkmenabat': <PIL.Image.Image image mode=RGB size=128x128>,
#  'surakarta': <PIL.Image.Image image mode=RGB size=128x128>,
#  'makati_city': <PIL.Image.Image image mode=RGB size=128x128>,
#  'cordoba': <PIL.Image.Image image mode=RGB size=128x128>,
#  'chelyabinsk': <PIL.Image.Image image mode=RGB size=128x128>,
#  'beijing': <PIL.Image.Image image mode=RGB size=128x128>,
#  'aarhus': <PIL.Image.Image image mode=RGB size=128x128>,
#  'genoa': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bergen': <PIL.Image.Image image mode=RGB size=128x128>,
#  'espoo': <PIL.Image.Image image mode=RGB size=128x128>,
#  'rohtak': <PIL.Image.Image image mode=RGB size=128x128>,
#  'trnava': <PIL.Image.Image image mode=RGB size=128x128>,
#  'escuintla': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kunming': <PIL.Image.Image image mode=RGB size=128x128>,
#  'jaipur': <PIL.Image.Image image mode=RGB size=128x128>,
#  'agra': <PIL.Image.Image image mode=RGB size=128x128>,
#  'pernik': <PIL.Image.Image image mode=RGB size=128x128>,
#  'okayama': <PIL.Image.Image image mode=RGB size=128x128>,
#  'xining': <PIL.Image.Image image mode=RGB size=128x128>,
#  'ho_chi_minh_city': <PIL.Image.Image image mode=RGB size=128x128>,
#  'baoding': <PIL.Image.Image image mode=RGB size=128x128>,
#  'hetauda': <PIL.Image.Image image mode=RGB size=128x128>,
#  'toprakkale': <PIL.Image.Image image mode=RGB size=128x128>,
#  'new_york': <PIL.Image.Image image mode=RGB size=128x128>,
#  'panama_city': <PIL.Image.Image image mode=RGB size=128x128>,
#  'las_vegas': <PIL.Image.Image image mode=RGB size=128x128>,
#  'ghazni': <PIL.Image.Image image mode=RGB size=128x128>,
#  'amman': <PIL.Image.Image image mode=RGB size=128x128>,
#  'pucallpa': <PIL.Image.Image image mode=RGB size=128x128>,
#  'philadelphia': <PIL.Image.Image image mode=RGB size=128x128>,
#  'swords': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kaifeng_chengguanzhen': <PIL.Image.Image image mode=RGB size=128x128>,
#  'tangerang': <PIL.Image.Image image mode=RGB size=128x128>,
#  "karbala'": <PIL.Image.Image image mode=RGB size=128x128>,
#  'antalya': <PIL.Image.Image image mode=RGB size=128x128>,
#  'caloocan_city': <PIL.Image.Image image mode=RGB size=128x128>,
#  'varanasi': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bydgoszcz': <PIL.Image.Image image mode=RGB size=128x128>,
#  'balikpapan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'karlovac': <PIL.Image.Image image mode=RGB size=128x128>,
#  'eindhoven': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bekasi': <PIL.Image.Image image mode=RGB size=128x128>,
#  'qingyuan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'saratov': <PIL.Image.Image image mode=RGB size=128x128>,
#  'pavlodar': <PIL.Image.Image image mode=RGB size=128x128>,
#  'liberia': <PIL.Image.Image image mode=RGB size=128x128>,
#  'coban': <PIL.Image.Image image mode=RGB size=128x128>,
#  'amadora': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kasur': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bogota': <PIL.Image.Image image mode=RGB size=128x128>,
#  'fuyang': <PIL.Image.Image image mode=RGB size=128x128>,
#  'piraeus': <PIL.Image.Image image mode=RGB size=128x128>,
#  'jakarta': <PIL.Image.Image image mode=RGB size=128x128>,
#  'city_of_calamba': <PIL.Image.Image image mode=RGB size=128x128>,
#  'hermosillo': <PIL.Image.Image image mode=RGB size=128x128>,
#  'damascus': <PIL.Image.Image image mode=RGB size=128x128>,
#  'hamburg': <PIL.Image.Image image mode=RGB size=128x128>,
#  'hohhot': <PIL.Image.Image image mode=RGB size=128x128>,
#  'san_marcos': <PIL.Image.Image image mode=RGB size=128x128>,
#  'catania': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bijie': <PIL.Image.Image image mode=RGB size=128x128>,
#  'al_basrah': <PIL.Image.Image image mode=RGB size=128x128>,
#  'maceio': <PIL.Image.Image image mode=RGB size=128x128>,
#  'carrefour': <PIL.Image.Image image mode=RGB size=128x128>,
#  'dubai': <PIL.Image.Image image mode=RGB size=128x128>,
#  'brno': <PIL.Image.Image image mode=RGB size=128x128>,
#  'murcia': <PIL.Image.Image image mode=RGB size=128x128>,
#  'nashville': <PIL.Image.Image image mode=RGB size=128x128>,
#  'chongqing': <PIL.Image.Image image mode=RGB size=128x128>,
#  'winterthur': <PIL.Image.Image image mode=RGB size=128x128>,
#  'daqing': <PIL.Image.Image image mode=RGB size=128x128>,
#  'daejeon': <PIL.Image.Image image mode=RGB size=128x128>,
#  'san_jose_el_viejo': <PIL.Image.Image image mode=RGB size=128x128>,
#  'brasilia': <PIL.Image.Image image mode=RGB size=128x128>,
#  'okara': <PIL.Image.Image image mode=RGB size=128x128>,
#  'dera_ismail_khan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'esbjerg': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kara-balta': <PIL.Image.Image image mode=RGB size=128x128>,
#  'cartagena': <PIL.Image.Image image mode=RGB size=128x128>,
#  'charlotte': <PIL.Image.Image image mode=RGB size=128x128>,
#  'balkh': <PIL.Image.Image image mode=RGB size=128x128>,
#  'warsaw': <PIL.Image.Image image mode=RGB size=128x128>,
#  'linyi': <PIL.Image.Image image mode=RGB size=128x128>,
#  'rijeka': <PIL.Image.Image image mode=RGB size=128x128>,
#  'uppsala': <PIL.Image.Image image mode=RGB size=128x128>,
#  'quanzhou': <PIL.Image.Image image mode=RGB size=128x128>,
#  'colombo': <PIL.Image.Image image mode=RGB size=128x128>,
#  'al_hudaydah': <PIL.Image.Image image mode=RGB size=128x128>,
#  'daegu': <PIL.Image.Image image mode=RGB size=128x128>,
#  'jinzhong': <PIL.Image.Image image mode=RGB size=128x128>,
#  "homyel'": <PIL.Image.Image image mode=RGB size=128x128>,
#  'leeds': <PIL.Image.Image image mode=RGB size=128x128>,
#  'taizhou': <PIL.Image.Image image mode=RGB size=128x128>,
#  'johor_bahru': <PIL.Image.Image image mode=RGB size=128x128>,
#  'toulouse': <PIL.Image.Image image mode=RGB size=128x128>,
#  'santo_domingo_de_los_colorados': <PIL.Image.Image image mode=RGB size=128x128>,
#  'chicago': <PIL.Image.Image image mode=RGB size=128x128>,
#  'naples': <PIL.Image.Image image mode=RGB size=128x128>,
#  'lucknow': <PIL.Image.Image image mode=RGB size=128x128>,
#  'edinburgh': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bristol': <PIL.Image.Image image mode=RGB size=128x128>,
#  'serang': <PIL.Image.Image image mode=RGB size=128x128>,
#  'zunyi': <PIL.Image.Image image mode=RGB size=128x128>,
#  'huizhou': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kumamoto': <PIL.Image.Image image mode=RGB size=128x128>,
#  'pekanbaru': <PIL.Image.Image image mode=RGB size=128x128>,
#  'sri_jayewardenepura_kotte': <PIL.Image.Image image mode=RGB size=128x128>,
#  'davangere': <PIL.Image.Image image mode=RGB size=128x128>,
#  'turku': <PIL.Image.Image image mode=RGB size=128x128>,
#  'trincomalee': <PIL.Image.Image image mode=RGB size=128x128>,
#  'charleroi': <PIL.Image.Image image mode=RGB size=128x128>,
#  'qaracuxur': <PIL.Image.Image image mode=RGB size=128x128>,
#  'moratuwa': <PIL.Image.Image image mode=RGB size=128x128>,
#  'roseville': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bordeaux': <PIL.Image.Image image mode=RGB size=128x128>,
#  'queluz': <PIL.Image.Image image mode=RGB size=128x128>,
#  'shiraz': <PIL.Image.Image image mode=RGB size=128x128>,
#  'liverpool': <PIL.Image.Image image mode=RGB size=128x128>,
#  'paris': <PIL.Image.Image image mode=RGB size=128x128>,
#  'goiania': <PIL.Image.Image image mode=RGB size=128x128>,
#  'montpellier': <PIL.Image.Image image mode=RGB size=128x128>,
#  'denpasar': <PIL.Image.Image image mode=RGB size=128x128>,
#  'hong_kong': <PIL.Image.Image image mode=RGB size=128x128>,
#  'erode': <PIL.Image.Image image mode=RGB size=128x128>,
#  'queens': <PIL.Image.Image image mode=RGB size=128x128>,
#  'saitama': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bahawalpur': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bella_vista': <PIL.Image.Image image mode=RGB size=128x128>,
#  'luohe': <PIL.Image.Image image mode=RGB size=128x128>,
#  'jinhua': <PIL.Image.Image image mode=RGB size=128x128>,
#  'guigang': <PIL.Image.Image image mode=RGB size=128x128>,
#  'ad_dammam': <PIL.Image.Image image mode=RGB size=128x128>,
#  'alajuela': <PIL.Image.Image image mode=RGB size=128x128>,
#  'sargodha': <PIL.Image.Image image mode=RGB size=128x128>,
#  'malaga': <PIL.Image.Image image mode=RGB size=128x128>,
#  'odesa': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bharatpur': <PIL.Image.Image image mode=RGB size=128x128>,
#  'timisoara': <PIL.Image.Image image mode=RGB size=128x128>,
#  'lodz': <PIL.Image.Image image mode=RGB size=128x128>,
#  'samarkand': <PIL.Image.Image image mode=RGB size=128x128>,
#  'jeddah': <PIL.Image.Image image mode=RGB size=128x128>,
#  'fushun': <PIL.Image.Image image mode=RGB size=128x128>,
#  'slavonski_brod': <PIL.Image.Image image mode=RGB size=128x128>,
#  'sialkot_city': <PIL.Image.Image image mode=RGB size=128x128>,
#  'cimahi': <PIL.Image.Image image mode=RGB size=128x128>,
#  'las_pinas_city': <PIL.Image.Image image mode=RGB size=128x128>,
#  'sakaidecho': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bannu': <PIL.Image.Image image mode=RGB size=128x128>,
#  'santo_domingo': <PIL.Image.Image image mode=RGB size=128x128>,
#  'anderlecht': <PIL.Image.Image image mode=RGB size=128x128>,
#  'korbach': <PIL.Image.Image image mode=RGB size=128x128>,
#  'aleysk': <PIL.Image.Image image mode=RGB size=128x128>,
#  'salta': <PIL.Image.Image image mode=RGB size=128x128>,
#  'saharanpur': <PIL.Image.Image image mode=RGB size=128x128>,
#  'puducherry': <PIL.Image.Image image mode=RGB size=128x128>,
#  'shiyan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bandar_lampung': <PIL.Image.Image image mode=RGB size=128x128>,
#  'mary': <PIL.Image.Image image mode=RGB size=128x128>,
#  'changzhi': <PIL.Image.Image image mode=RGB size=128x128>,
#  'surabaya': <PIL.Image.Image image mode=RGB size=128x128>,
#  'varna': <PIL.Image.Image image mode=RGB size=128x128>,
#  'quillacollo': <PIL.Image.Image image mode=RGB size=128x128>,
#  'columbus': <PIL.Image.Image image mode=RGB size=128x128>,
#  'barcelona': <PIL.Image.Image image mode=RGB size=128x128>,
#  'amravati': <PIL.Image.Image image mode=RGB size=128x128>,
#  'puntarenas': <PIL.Image.Image image mode=RGB size=128x128>,
#  'san_bernardo': <PIL.Image.Image image mode=RGB size=128x128>,
#  'xiamen': <PIL.Image.Image image mode=RGB size=128x128>,
#  'zhuzhou': <PIL.Image.Image image mode=RGB size=128x128>,
#  'blantyre': <PIL.Image.Image image mode=RGB size=128x128>,
#  'yulin': <PIL.Image.Image image mode=RGB size=128x128>,
#  'perm': <PIL.Image.Image image mode=RGB size=128x128>,
#  'morelia': <PIL.Image.Image image mode=RGB size=128x128>,
#  'lahore': <PIL.Image.Image image mode=RGB size=128x128>,
#  'ostseebad_kuhlungsborn': <PIL.Image.Image image mode=RGB size=128x128>,
#  'masaya': <PIL.Image.Image image mode=RGB size=128x128>,
#  'netanya': <PIL.Image.Image image mode=RGB size=128x128>,
#  'nanchang': <PIL.Image.Image image mode=RGB size=128x128>,
#  'rajshahi': <PIL.Image.Image image mode=RGB size=128x128>,
#  'chaozhou': <PIL.Image.Image image mode=RGB size=128x128>,
#  'wuhan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'san_vicente': <PIL.Image.Image image mode=RGB size=128x128>,
#  'ciudad_guayana': <PIL.Image.Image image mode=RGB size=128x128>,
#  'matagalpa': <PIL.Image.Image image mode=RGB size=128x128>,
#  'dobrich': <PIL.Image.Image image mode=RGB size=128x128>,
#  'birmingham': <PIL.Image.Image image mode=RGB size=128x128>,
#  'thane': <PIL.Image.Image image mode=RGB size=128x128>,
#  'nanyang': <PIL.Image.Image image mode=RGB size=128x128>,
#  'cucuta': <PIL.Image.Image image mode=RGB size=128x128>,
#  'ashgabat': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kaesong': <PIL.Image.Image image mode=RGB size=128x128>,
#  'ciudad_del_este': <PIL.Image.Image image mode=RGB size=128x128>,
#  'iquitos': <PIL.Image.Image image mode=RGB size=128x128>,
#  'novi_pazar': <PIL.Image.Image image mode=RGB size=128x128>,
#  'ankara': <PIL.Image.Image image mode=RGB size=128x128>,
#  'almaty': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kallithea': <PIL.Image.Image image mode=RGB size=128x128>,
#  'hanoi': <PIL.Image.Image image mode=RGB size=128x128>,
#  'moscow': <PIL.Image.Image image mode=RGB size=128x128>,
#  'denver': <PIL.Image.Image image mode=RGB size=128x128>,
#  'krakow': <PIL.Image.Image image mode=RGB size=128x128>,
#  'vantaa': <PIL.Image.Image image mode=RGB size=128x128>,
#  'faisalabad': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bishkek': <PIL.Image.Image image mode=RGB size=128x128>,
#  'rishon_leziyyon': <PIL.Image.Image image mode=RGB size=128x128>,
#  'tando_allahyar': <PIL.Image.Image image mode=RGB size=128x128>,
#  'aleppo': <PIL.Image.Image image mode=RGB size=128x128>,
#  'ostrava': <PIL.Image.Image image mode=RGB size=128x128>,
#  'san_antonio': <PIL.Image.Image image mode=RGB size=128x128>,
#  'boston': <PIL.Image.Image image mode=RGB size=128x128>,
#  'baltimore': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bronx': <PIL.Image.Image image mode=RGB size=128x128>,
#  'delmas': <PIL.Image.Image image mode=RGB size=128x128>,
#  'subotica': <PIL.Image.Image image mode=RGB size=128x128>,
#  'memphis': <PIL.Image.Image image mode=RGB size=128x128>,
#  'brussels': <PIL.Image.Image image mode=RGB size=128x128>,
#  'chiba': <PIL.Image.Image image mode=RGB size=128x128>,
#  'lisbon': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bhavnagar': <PIL.Image.Image image mode=RGB size=128x128>,
#  'ottawa': <PIL.Image.Image image mode=RGB size=128x128>,
#  'pokhara': <PIL.Image.Image image mode=RGB size=128x128>,
#  'aurangabad': <PIL.Image.Image image mode=RGB size=128x128>,
#  'zagreb': <PIL.Image.Image image mode=RGB size=128x128>,
#  'galati': <PIL.Image.Image image mode=RGB size=128x128>,
#  'hengyang': <PIL.Image.Image image mode=RGB size=128x128>,
#  'nagpur': <PIL.Image.Image image mode=RGB size=128x128>,
#  'oruro': <PIL.Image.Image image mode=RGB size=128x128>,
#  'guantanamo': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kayseri': <PIL.Image.Image image mode=RGB size=128x128>,
#  'jiangmen': <PIL.Image.Image image mode=RGB size=128x128>,
#  'utrecht': <PIL.Image.Image image mode=RGB size=128x128>,
#  'nukus': <PIL.Image.Image image mode=RGB size=128x128>,
#  'san_miguel_de_tucuman': <PIL.Image.Image image mode=RGB size=128x128>,
#  'belem': <PIL.Image.Image image mode=RGB size=128x128>,
#  'sacramento': <PIL.Image.Image image mode=RGB size=128x128>,
#  'san_jose': <PIL.Image.Image image mode=RGB size=128x128>,
#  'jacmel': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kosice': <PIL.Image.Image image mode=RGB size=128x128>,
#  'can_tho': <PIL.Image.Image image mode=RGB size=128x128>,
#  'natal': <PIL.Image.Image image mode=RGB size=128x128>,
#  'ribeirao_preto': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kandy': <PIL.Image.Image image mode=RGB size=128x128>,
#  'antwerp': <PIL.Image.Image image mode=RGB size=128x128>,
#  'colon': <PIL.Image.Image image mode=RGB size=128x128>,
#  'dallas': <PIL.Image.Image image mode=RGB size=128x128>,
#  'novi_sad': <PIL.Image.Image image mode=RGB size=128x128>,
#  'cuttack': <PIL.Image.Image image mode=RGB size=128x128>,
#  'mawlamyine': <PIL.Image.Image image mode=RGB size=128x128>,
#  'zigong': <PIL.Image.Image image mode=RGB size=128x128>,
#  'sittwe': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kota': <PIL.Image.Image image mode=RGB size=128x128>,
#  'essen': <PIL.Image.Image image mode=RGB size=128x128>,
#  'fortaleza': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kuwait_city': <PIL.Image.Image image mode=RGB size=128x128>,
#  'yangzhou': <PIL.Image.Image image mode=RGB size=128x128>,
#  'lucerne': <PIL.Image.Image image mode=RGB size=128x128>,
#  'linkoping': <PIL.Image.Image image mode=RGB size=128x128>,
#  'karachi': <PIL.Image.Image image mode=RGB size=128x128>,
#  'hungnam': <PIL.Image.Image image mode=RGB size=128x128>,
#  'ulhasnagar': <PIL.Image.Image image mode=RGB size=128x128>,
#  'shaoxing': <PIL.Image.Image image mode=RGB size=128x128>,
#  'battambang': <PIL.Image.Image image mode=RGB size=128x128>,
#  'vahdat': <PIL.Image.Image image mode=RGB size=128x128>,
#  'wuxi': <PIL.Image.Image image mode=RGB size=128x128>,
#  'thiruvananthapuram': <PIL.Image.Image image mode=RGB size=128x128>,
#  'ganzhou': <PIL.Image.Image image mode=RGB size=128x128>,
#  'tejen': <PIL.Image.Image image mode=RGB size=128x128>,
#  'shantou': <PIL.Image.Image image mode=RGB size=128x128>,
#  'maracaibo': <PIL.Image.Image image mode=RGB size=128x128>,
#  'ningbo': <PIL.Image.Image image mode=RGB size=128x128>,
#  'istaravshan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'ghaziabad': <PIL.Image.Image image mode=RGB size=128x128>,
#  'athens': <PIL.Image.Image image mode=RGB size=128x128>,
#  'dayr_az_zawr': <PIL.Image.Image image mode=RGB size=128x128>,
#  'brest': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bago': <PIL.Image.Image image mode=RGB size=128x128>,
#  'sanaa': <PIL.Image.Image image mode=RGB size=128x128>,
#  'la_paz': <PIL.Image.Image image mode=RGB size=128x128>,
#  'isfara': <PIL.Image.Image image mode=RGB size=128x128>,
#  'brooklyn': <PIL.Image.Image image mode=RGB size=128x128>,
#  'puerto_plata': <PIL.Image.Image image mode=RGB size=128x128>,
#  'novosibirsk': <PIL.Image.Image image mode=RGB size=128x128>,
#  'mississauga': <PIL.Image.Image image mode=RGB size=128x128>,
#  'noumea': <PIL.Image.Image image mode=RGB size=128x128>,
#  'volgograd': <PIL.Image.Image image mode=RGB size=128x128>,
#  'port-au-prince': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bursa': <PIL.Image.Image image mode=RGB size=128x128>,
#  'baojishi': <PIL.Image.Image image mode=RGB size=128x128>,
#  'funchal': <PIL.Image.Image image mode=RGB size=128x128>,
#  'babruysk': <PIL.Image.Image image mode=RGB size=128x128>,
#  'guankou': <PIL.Image.Image image mode=RGB size=128x128>,
#  'stuttgart': <PIL.Image.Image image mode=RGB size=128x128>,
#  'suwon': <PIL.Image.Image image mode=RGB size=128x128>,
#  'oklahoma_city': <PIL.Image.Image image mode=RGB size=128x128>,
#  'nampula': <PIL.Image.Image image mode=RGB size=128x128>,
#  'cacak': <PIL.Image.Image image mode=RGB size=128x128>,
#  'les_cayes': <PIL.Image.Image image mode=RGB size=128x128>,
#  'medellin': <PIL.Image.Image image mode=RGB size=128x128>,
#  'port-de-paix': <PIL.Image.Image image mode=RGB size=128x128>,
#  'dublin': <PIL.Image.Image image mode=RGB size=128x128>,
#  "az_zarqa'": <PIL.Image.Image image mode=RGB size=128x128>,
#  'helsinki': <PIL.Image.Image image mode=RGB size=128x128>,
#  'barquisimeto': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kurnool': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kabul': <PIL.Image.Image image mode=RGB size=128x128>,
#  'jyvaskyla': <PIL.Image.Image image mode=RGB size=128x128>,
#  'ulsan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bruges': <PIL.Image.Image image mode=RGB size=128x128>,
#  'ramgundam': <PIL.Image.Image image mode=RGB size=128x128>,
#  'burgas': <PIL.Image.Image image mode=RGB size=128x128>,
#  'muzaffarnagar': <PIL.Image.Image image mode=RGB size=128x128>,
#  'dazhou': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bahia_blanca': <PIL.Image.Image image mode=RGB size=128x128>,
#  'houston': <PIL.Image.Image image mode=RGB size=128x128>,
#  'tucson': <PIL.Image.Image image mode=RGB size=128x128>,
#  'david': <PIL.Image.Image image mode=RGB size=128x128>,
#  'cochabamba': <PIL.Image.Image image mode=RGB size=128x128>,
#  'handan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'busan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'lviv': <PIL.Image.Image image mode=RGB size=128x128>,
#  'haikou': <PIL.Image.Image image mode=RGB size=128x128>,
#  'keelung': <PIL.Image.Image image mode=RGB size=128x128>,
#  'taoyuan_district': <PIL.Image.Image image mode=RGB size=128x128>,
#  'sebastopol': <PIL.Image.Image image mode=RGB size=128x128>,
#  'ciudad_nezahualcoyotl': <PIL.Image.Image image mode=RGB size=128x128>,
#  'lahti': <PIL.Image.Image image mode=RGB size=128x128>,
#  'trondheim': <PIL.Image.Image image mode=RGB size=128x128>,
#  'baotou': <PIL.Image.Image image mode=RGB size=128x128>,
#  'guarulhos': <PIL.Image.Image image mode=RGB size=128x128>,
#  'manado': <PIL.Image.Image image mode=RGB size=128x128>,
#  'belo_horizonte': <PIL.Image.Image image mode=RGB size=128x128>,
#  'stara_zagora': <PIL.Image.Image image mode=RGB size=128x128>,
#  'milan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'faridabad': <PIL.Image.Image image mode=RGB size=128x128>,
#  'balykchy': <PIL.Image.Image image mode=RGB size=128x128>,
#  'wuhu': <PIL.Image.Image image mode=RGB size=128x128>,
#  'rotterdam': <PIL.Image.Image image mode=RGB size=128x128>,
#  'negombo': <PIL.Image.Image image mode=RGB size=128x128>,
#  'jerusalem': <PIL.Image.Image image mode=RGB size=128x128>,
#  'santa_cruz': <PIL.Image.Image image mode=RGB size=128x128>,
#  'phoenix': <PIL.Image.Image image mode=RGB size=128x128>,
#  'cluj-napoca': <PIL.Image.Image image mode=RGB size=128x128>,
#  'taipei': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bhagalpur': <PIL.Image.Image image mode=RGB size=128x128>,
#  'longyan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'coimbatore': <PIL.Image.Image image mode=RGB size=128x128>,
#  'jalalabad': <PIL.Image.Image image mode=RGB size=128x128>,
#  'temixco': <PIL.Image.Image image mode=RGB size=128x128>,
#  'jalal-abad': <PIL.Image.Image image mode=RGB size=128x128>,
#  'samara': <PIL.Image.Image image mode=RGB size=128x128>,
#  'jalapa': <PIL.Image.Image image mode=RGB size=128x128>,
#  'vancouver': <PIL.Image.Image image mode=RGB size=128x128>,
#  'el_paso': <PIL.Image.Image image mode=RGB size=128x128>,
#  'salvador': <PIL.Image.Image image mode=RGB size=128x128>,
#  'cumana': <PIL.Image.Image image mode=RGB size=128x128>,
#  'dundalk': <PIL.Image.Image image mode=RGB size=128x128>,
#  'toronto': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kirkuk': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bilbao': <PIL.Image.Image image mode=RGB size=128x128>,
#  'dharan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'vina_del_mar': <PIL.Image.Image image mode=RGB size=128x128>,
#  'linz': <PIL.Image.Image image mode=RGB size=128x128>,
#  'zapopan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'sharjah': <PIL.Image.Image image mode=RGB size=128x128>,
#  'mexico_city': <PIL.Image.Image image mode=RGB size=128x128>,
#  'gothenburg': <PIL.Image.Image image mode=RGB size=128x128>,
#  'austin': <PIL.Image.Image image mode=RGB size=128x128>,
#  'aracaju': <PIL.Image.Image image mode=RGB size=128x128>,
#  'jaboatao': <PIL.Image.Image image mode=RGB size=128x128>,
#  'nice': <PIL.Image.Image image mode=RGB size=128x128>,
#  'al_mukalla': <PIL.Image.Image image mode=RGB size=128x128>,
#  'teresina': <PIL.Image.Image image mode=RGB size=128x128>,
#  'tel_aviv-yafo': <PIL.Image.Image image mode=RGB size=128x128>,
#  'istanbul': <PIL.Image.Image image mode=RGB size=128x128>,
#  'liege': <PIL.Image.Image image mode=RGB size=128x128>,
#  'copenhagen': <PIL.Image.Image image mode=RGB size=128x128>,
#  'rajkot': <PIL.Image.Image image mode=RGB size=128x128>,
#  'oslo': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bern': <PIL.Image.Image image mode=RGB size=128x128>,
#  'yangjiang': <PIL.Image.Image image mode=RGB size=128x128>,
#  'poprad': <PIL.Image.Image image mode=RGB size=128x128>,
#  'muzaffarabad': <PIL.Image.Image image mode=RGB size=128x128>,
#  'gdansk': <PIL.Image.Image image mode=RGB size=128x128>,
#  'muscat': <PIL.Image.Image image mode=RGB size=128x128>,
#  'pasig_city': <PIL.Image.Image image mode=RGB size=128x128>,
#  'sao_jose_dos_campos': <PIL.Image.Image image mode=RGB size=128x128>,
#  'drammen': <PIL.Image.Image image mode=RGB size=128x128>,
#  'usti_nad_labem': <PIL.Image.Image image mode=RGB size=128x128>,
#  'san_luis_potosi': <PIL.Image.Image image mode=RGB size=128x128>,
#  'recife': <PIL.Image.Image image mode=RGB size=128x128>,
#  'sandnes': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bilaspur': <PIL.Image.Image image mode=RGB size=128x128>,
#  'khulna': <PIL.Image.Image image mode=RGB size=128x128>,
#  'jacksonville': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bozhou': <PIL.Image.Image image mode=RGB size=128x128>,
#  '`ibri': <PIL.Image.Image image mode=RGB size=128x128>,
#  'yichun': <PIL.Image.Image image mode=RGB size=128x128>,
#  'vasteras': <PIL.Image.Image image mode=RGB size=128x128>,
#  'solapur': <PIL.Image.Image image mode=RGB size=128x128>,
#  'brampton': <PIL.Image.Image image mode=RGB size=128x128>,
#  'el_progreso': <PIL.Image.Image image mode=RGB size=128x128>,
#  'homs': <PIL.Image.Image image mode=RGB size=128x128>,
#  'detroit': <PIL.Image.Image image mode=RGB size=128x128>,
#  'latakia': <PIL.Image.Image image mode=RGB size=128x128>,
#  'guilin': <PIL.Image.Image image mode=RGB size=128x128>,
#  'monteria': <PIL.Image.Image image mode=RGB size=128x128>,
#  'hebron': <PIL.Image.Image image mode=RGB size=128x128>,
#  'heshan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'petaling_jaya': <PIL.Image.Image image mode=RGB size=128x128>,
#  'turin': <PIL.Image.Image image mode=RGB size=128x128>,
#  'guangzhou': <PIL.Image.Image image mode=RGB size=128x128>,
#  'tangshan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'graz': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kaohsiung': <PIL.Image.Image image mode=RGB size=128x128>,
#  'marseille': <PIL.Image.Image image mode=RGB size=128x128>,
#  'khujand': <PIL.Image.Image image mode=RGB size=128x128>,
#  'pursat': <PIL.Image.Image image mode=RGB size=128x128>,
#  'nanning': <PIL.Image.Image image mode=RGB size=128x128>,
#  'dhaka': <PIL.Image.Image image mode=RGB size=128x128>,
#  'presov': <PIL.Image.Image image mode=RGB size=128x128>,
#  'shymkent': <PIL.Image.Image image mode=RGB size=128x128>,
#  'palermo': <PIL.Image.Image image mode=RGB size=128x128>,
#  'maturin': <PIL.Image.Image image mode=RGB size=128x128>,
#  'hat_yai': <PIL.Image.Image image mode=RGB size=128x128>,
#  'jutiapa': <PIL.Image.Image image mode=RGB size=128x128>,
#  'lanzhou': <PIL.Image.Image image mode=RGB size=128x128>,
#  'mumbai': <PIL.Image.Image image mode=RGB size=128x128>,
#  'managua': <PIL.Image.Image image mode=RGB size=128x128>,
#  'encarnacion': <PIL.Image.Image image mode=RGB size=128x128>,
#  'tovuz': <PIL.Image.Image image mode=RGB size=128x128>,
#  'san_cristobal': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bredasdorp': <PIL.Image.Image image mode=RGB size=128x128>,
#  'vishakhapatnam': <PIL.Image.Image image mode=RGB size=128x128>,
#  'pedro_juan_caballero': <PIL.Image.Image image mode=RGB size=128x128>,
#  'tashkent': <PIL.Image.Image image mode=RGB size=128x128>,
#  'sendai': <PIL.Image.Image image mode=RGB size=128x128>,
#  'tampere': <PIL.Image.Image image mode=RGB size=128x128>,
#  'putian': <PIL.Image.Image image mode=RGB size=128x128>,
#  'sapporo': <PIL.Image.Image image mode=RGB size=128x128>,
#  'salzburg': <PIL.Image.Image image mode=RGB size=128x128>,
#  'cork': <PIL.Image.Image image mode=RGB size=128x128>,
#  'tasikmalaya': <PIL.Image.Image image mode=RGB size=128x128>,
#  'jhansi': <PIL.Image.Image image mode=RGB size=128x128>,
#  'anshan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'fresno': <PIL.Image.Image image mode=RGB size=128x128>,
#  'sumqayit': <PIL.Image.Image image mode=RGB size=128x128>,
#  'meerut': <PIL.Image.Image image mode=RGB size=128x128>,
#  "huai'an": <PIL.Image.Image image mode=RGB size=128x128>,
#  'trujillo': <PIL.Image.Image image mode=RGB size=128x128>,
#  'huancayo': <PIL.Image.Image image mode=RGB size=128x128>,
#  'manaus': <PIL.Image.Image image mode=RGB size=128x128>,
#  'sahiwal': <PIL.Image.Image image mode=RGB size=128x128>,
#  'santa_clara': <PIL.Image.Image image mode=RGB size=128x128>,
#  'buenos_aires': <PIL.Image.Image image mode=RGB size=128x128>,
#  'leon_de_los_aldama': <PIL.Image.Image image mode=RGB size=128x128>,
#  'lankaran': <PIL.Image.Image image mode=RGB size=128x128>,
#  'tabuk': <PIL.Image.Image image mode=RGB size=128x128>,
#  'tyumen': <PIL.Image.Image image mode=RGB size=128x128>,
#  'vellore': <PIL.Image.Image image mode=RGB size=128x128>,
#  'jodhpur': <PIL.Image.Image image mode=RGB size=128x128>,
#  'suqian': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kotli': <PIL.Image.Image image mode=RGB size=128x128>,
#  'la_romana': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kenitra': <PIL.Image.Image image mode=RGB size=128x128>,
#  'geneva': <PIL.Image.Image image mode=RGB size=128x128>,
#  'zibo': <PIL.Image.Image image mode=RGB size=128x128>,
#  'amritsar': <PIL.Image.Image image mode=RGB size=128x128>,
#  'nagoya': <PIL.Image.Image image mode=RGB size=128x128>,
#  'prague': <PIL.Image.Image image mode=RGB size=128x128>,
#  'padang': <PIL.Image.Image image mode=RGB size=128x128>,
#  'poznan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'singapore': <PIL.Image.Image image mode=RGB size=128x128>,
#  'cape_coral': <PIL.Image.Image image mode=RGB size=128x128>,
#  'antofagasta': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bareilly': <PIL.Image.Image image mode=RGB size=128x128>,
#  'zamboanga_city': <PIL.Image.Image image mode=RGB size=128x128>,
#  'sukkur': <PIL.Image.Image image mode=RGB size=128x128>,
#  'chon_buri': <PIL.Image.Image image mode=RGB size=128x128>,
#  'cologne': <PIL.Image.Image image mode=RGB size=128x128>,
#  'nantong': <PIL.Image.Image image mode=RGB size=128x128>,
#  'san_lorenzo': <PIL.Image.Image image mode=RGB size=128x128>,
#  'shaoguan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'taiyuan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'manhattan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'mianyang': <PIL.Image.Image image mode=RGB size=128x128>,
#  'pardubice': <PIL.Image.Image image mode=RGB size=128x128>,
#  'qom': <PIL.Image.Image image mode=RGB size=128x128>,
#  'gwalior': <PIL.Image.Image image mode=RGB size=128x128>,
#  'edmonton': <PIL.Image.Image image mode=RGB size=128x128>,
#  'medina': <PIL.Image.Image image mode=RGB size=128x128>,
#  'tijuana': <PIL.Image.Image image mode=RGB size=128x128>,
#  'waterford': <PIL.Image.Image image mode=RGB size=128x128>,
#  'san_diego': <PIL.Image.Image image mode=RGB size=128x128>,
#  'jamshedpur': <PIL.Image.Image image mode=RGB size=128x128>,
#  'ipoh': <PIL.Image.Image image mode=RGB size=128x128>,
#  'cacem': <PIL.Image.Image image mode=RGB size=128x128>,
#  'ranchi': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kakinada': <PIL.Image.Image image mode=RGB size=128x128>,
#  'montreal': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kristiansand': <PIL.Image.Image image mode=RGB size=128x128>,
#  'fuzhou': <PIL.Image.Image image mode=RGB size=128x128>,
#  'irbid': <PIL.Image.Image image mode=RGB size=128x128>,
#  'as_sulaymaniyah': <PIL.Image.Image image mode=RGB size=128x128>,
#  'changchun': <PIL.Image.Image image mode=RGB size=128x128>,
#  'piura': <PIL.Image.Image image mode=RGB size=128x128>,
#  'milwaukee': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bukhara': <PIL.Image.Image image mode=RGB size=128x128>,
#  'jiangyin': <PIL.Image.Image image mode=RGB size=128x128>,
#  'corrientes': <PIL.Image.Image image mode=RGB size=128x128>,
#  'ludhiana': <PIL.Image.Image image mode=RGB size=128x128>,
#  'raipur': <PIL.Image.Image image mode=RGB size=128x128>,
#  'florence': <PIL.Image.Image image mode=RGB size=128x128>,
#  'sao_bernardo_do_campo': <PIL.Image.Image image mode=RGB size=128x128>,
#  'yekaterinburg': <PIL.Image.Image image mode=RGB size=128x128>,
#  'riyadh': <PIL.Image.Image image mode=RGB size=128x128>,
#  'karakol': <PIL.Image.Image image mode=RGB size=128x128>,
#  'xinyang': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bhilai': <PIL.Image.Image image mode=RGB size=128x128>,
#  'wonsan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kuopio': <PIL.Image.Image image mode=RGB size=128x128>,
#  'albuquerque': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kampong_chhnang': <PIL.Image.Image image mode=RGB size=128x128>,
#  'berlin': <PIL.Image.Image image mode=RGB size=128x128>,
#  'esteli': <PIL.Image.Image image mode=RGB size=128x128>,
#  'dera_ghazi_khan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'biratnagar': <PIL.Image.Image image mode=RGB size=128x128>,
#  'balkanabat': <PIL.Image.Image image mode=RGB size=128x128>,
#  'changshu': <PIL.Image.Image image mode=RGB size=128x128>,
#  'krasnoyarsk': <PIL.Image.Image image mode=RGB size=128x128>,
#  'arica': <PIL.Image.Image image mode=RGB size=128x128>,
#  'jalgaon': <PIL.Image.Image image mode=RGB size=128x128>,
#  'winnipeg': <PIL.Image.Image image mode=RGB size=128x128>,
#  'zhanjiang': <PIL.Image.Image image mode=RGB size=128x128>,
#  'jining': <PIL.Image.Image image mode=RGB size=128x128>,
#  'shenzhen': <PIL.Image.Image image mode=RGB size=128x128>,
#  'gardez': <PIL.Image.Image image mode=RGB size=128x128>,
#  'ahvaz': <PIL.Image.Image image mode=RGB size=128x128>,
#  'valencia': <PIL.Image.Image image mode=RGB size=128x128>,
#  'la_chorrera': <PIL.Image.Image image mode=RGB size=128x128>,
#  'dnipro': <PIL.Image.Image image mode=RGB size=128x128>,
#  'lampang': <PIL.Image.Image image mode=RGB size=128x128>,
#  'jinotega': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bratislava': <PIL.Image.Image image mode=RGB size=128x128>,
#  'coimbra': <PIL.Image.Image image mode=RGB size=128x128>,
#  'niigata': <PIL.Image.Image image mode=RGB size=128x128>,
#  'wroclaw': <PIL.Image.Image image mode=RGB size=128x128>,
#  'shijiazhuang': <PIL.Image.Image image mode=RGB size=128x128>,
#  'jinan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'ceske_budejovice': <PIL.Image.Image image mode=RGB size=128x128>,
#  'muzaffarpur': <PIL.Image.Image image mode=RGB size=128x128>,
#  'islamabad': <PIL.Image.Image image mode=RGB size=128x128>,
#  'semarang': <PIL.Image.Image image mode=RGB size=128x128>,
#  'tabriz': <PIL.Image.Image image mode=RGB size=128x128>,
#  'harbin': <PIL.Image.Image image mode=RGB size=128x128>,
#  'sao_joao_da_madeira': <PIL.Image.Image image mode=RGB size=128x128>,
#  'szeged': <PIL.Image.Image image mode=RGB size=128x128>,
#  'amsterdam': <PIL.Image.Image image mode=RGB size=128x128>,
#  'trencin': <PIL.Image.Image image mode=RGB size=128x128>,
#  'hyderabad': <PIL.Image.Image image mode=RGB size=128x128>,
#  'leskovac': <PIL.Image.Image image mode=RGB size=128x128>,
#  'erbil': <PIL.Image.Image image mode=RGB size=128x128>,
#  'qinzhou': <PIL.Image.Image image mode=RGB size=128x128>,
#  'yiwu': <PIL.Image.Image image mode=RGB size=128x128>,
#  'osaka': <PIL.Image.Image image mode=RGB size=128x128>,
#  'nantes': <PIL.Image.Image image mode=RGB size=128x128>,
#  'constanta': <PIL.Image.Image image mode=RGB size=128x128>,
#  'nyiregyhaza': <PIL.Image.Image image mode=RGB size=128x128>,
#  'jabalpur': <PIL.Image.Image image mode=RGB size=128x128>,
#  'aalborg': <PIL.Image.Image image mode=RGB size=128x128>,
#  'dalian': <PIL.Image.Image image mode=RGB size=128x128>,
#  'abadan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'nay_pyi_taw': <PIL.Image.Image image mode=RGB size=128x128>,
#  'comilla': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bologna': <PIL.Image.Image image mode=RGB size=128x128>,
#  'the_woodlands': <PIL.Image.Image image mode=RGB size=128x128>,
#  'aden': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kandahar': <PIL.Image.Image image mode=RGB size=128x128>,
#  'xianyang': <PIL.Image.Image image mode=RGB size=128x128>,
#  'cebu_city': <PIL.Image.Image image mode=RGB size=128x128>,
#  'manchester': <PIL.Image.Image image mode=RGB size=128x128>,
#  'hamamatsu': <PIL.Image.Image image mode=RGB size=128x128>,
#  'tokyo': <PIL.Image.Image image mode=RGB size=128x128>,
#  'quezon_city': <PIL.Image.Image image mode=RGB size=128x128>,
#  'stavanger': <PIL.Image.Image image mode=RGB size=128x128>,
#  'tripoli': <PIL.Image.Image image mode=RGB size=128x128>,
#  'samarinda': <PIL.Image.Image image mode=RGB size=128x128>,
#  'cap-haitien': <PIL.Image.Image image mode=RGB size=128x128>,
#  'cuenca': <PIL.Image.Image image mode=RGB size=128x128>,
#  'mosul': <PIL.Image.Image image mode=RGB size=128x128>,
#  'pune': <PIL.Image.Image image mode=RGB size=128x128>,
#  'delhi': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kawasaki': <PIL.Image.Image image mode=RGB size=128x128>,
#  'yunfu': <PIL.Image.Image image mode=RGB size=128x128>,
#  'shanghai': <PIL.Image.Image image mode=RGB size=128x128>,
#  'weifang': <PIL.Image.Image image mode=RGB size=128x128>,
#  'maracay': <PIL.Image.Image image mode=RGB size=128x128>,
#  'mar_del_plata': <PIL.Image.Image image mode=RGB size=128x128>,
#  'braga': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kalyan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'pathein': <PIL.Image.Image image mode=RGB size=128x128>,
#  'plovdiv': <PIL.Image.Image image mode=RGB size=128x128>,
#  'ashdod': <PIL.Image.Image image mode=RGB size=128x128>,
#  'izmir': <PIL.Image.Image image mode=RGB size=128x128>,
#  'rome': <PIL.Image.Image image mode=RGB size=128x128>,
#  'tehran': <PIL.Image.Image image mode=RGB size=128x128>,
#  'osasco': <PIL.Image.Image image mode=RGB size=128x128>,
#  'yancheng': <PIL.Image.Image image mode=RGB size=128x128>,
#  'wenzhou': <PIL.Image.Image image mode=RGB size=128x128>,
#  'sorocaba': <PIL.Image.Image image mode=RGB size=128x128>,
#  'guiyang': <PIL.Image.Image image mode=RGB size=128x128>,
#  'chengdu': <PIL.Image.Image image mode=RGB size=128x128>,
#  'lugano': <PIL.Image.Image image mode=RGB size=128x128>,
#  'la_lima': <PIL.Image.Image image mode=RGB size=128x128>,
#  'vejle': <PIL.Image.Image image mode=RGB size=128x128>,
#  'abu_dhabi': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kyoto': <PIL.Image.Image image mode=RGB size=128x128>,
#  'changde': <PIL.Image.Image image mode=RGB size=128x128>,
#  'malmo': <PIL.Image.Image image mode=RGB size=128x128>,
#  'vila_nova_de_gaia': <PIL.Image.Image image mode=RGB size=128x128>,
#  'santo_andre': <PIL.Image.Image image mode=RGB size=128x128>,
#  'pleven': <PIL.Image.Image image mode=RGB size=128x128>,
#  'strasbourg': <PIL.Image.Image image mode=RGB size=128x128>,
#  'zabid': <PIL.Image.Image image mode=RGB size=128x128>,
#  'sangli': <PIL.Image.Image image mode=RGB size=128x128>,
#  'salalah': <PIL.Image.Image image mode=RGB size=128x128>,
#  'ajmer': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bhopal': <PIL.Image.Image image mode=RGB size=128x128>,
#  "lu'an": <PIL.Image.Image image mode=RGB size=128x128>,
#  'asuncion': <PIL.Image.Image image mode=RGB size=128x128>,
#  'gwangju': <PIL.Image.Image image mode=RGB size=128x128>,
#  'huainan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'madurai': <PIL.Image.Image image mode=RGB size=128x128>,
#  'chennai': <PIL.Image.Image image mode=RGB size=128x128>,
#  'olomouc': <PIL.Image.Image image mode=RGB size=128x128>,
#  'jaffna': <PIL.Image.Image image mode=RGB size=128x128>,
#  'si_racha': <PIL.Image.Image image mode=RGB size=128x128>,
#  'inashiki': <PIL.Image.Image image mode=RGB size=128x128>,
#  'puerto_limon': <PIL.Image.Image image mode=RGB size=128x128>,
#  'barinas': <PIL.Image.Image image mode=RGB size=128x128>,
#  'groningen': <PIL.Image.Image image mode=RGB size=128x128>,
#  'shenyang': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bandung': <PIL.Image.Image image mode=RGB size=128x128>,
#  'jieyang': <PIL.Image.Image image mode=RGB size=128x128>,
#  'shah_alam': <PIL.Image.Image image mode=RGB size=128x128>,
#  'hradec_kralove': <PIL.Image.Image image mode=RGB size=128x128>,
#  'seattle': <PIL.Image.Image image mode=RGB size=128x128>,
#  'namangan': <PIL.Image.Image image mode=RGB size=128x128>,
#  'szczecin': <PIL.Image.Image image mode=RGB size=128x128>,
#  'sonsonate': <PIL.Image.Image image mode=RGB size=128x128>,
#  'hamhung': <PIL.Image.Image image mode=RGB size=128x128>,
#  'vadodara': <PIL.Image.Image image mode=RGB size=128x128>,
#  'banjarmasin': <PIL.Image.Image image mode=RGB size=128x128>,
#  'santa_ana': <PIL.Image.Image image mode=RGB size=128x128>,
#  'luoyang': <PIL.Image.Image image mode=RGB size=128x128>,
#  'gujrat': <PIL.Image.Image image mode=RGB size=128x128>,
#  'akola': <PIL.Image.Image image mode=RGB size=128x128>,
#  'valparaiso': <PIL.Image.Image image mode=RGB size=128x128>,
#  'tarija': <PIL.Image.Image image mode=RGB size=128x128>,
#  'miskolc': <PIL.Image.Image image mode=RGB size=128x128>,
#  'general_santos': <PIL.Image.Image image mode=RGB size=128x128>,
#  'innsbruck': <PIL.Image.Image image mode=RGB size=128x128>,
#  'camaguey': <PIL.Image.Image image mode=RGB size=128x128>,
#  'gorakhpur': <PIL.Image.Image image mode=RGB size=128x128>,
#  'changsha': <PIL.Image.Image image mode=RGB size=128x128>,
#  'monterrey': <PIL.Image.Image image mode=RGB size=128x128>,
#  'guntur': <PIL.Image.Image image mode=RGB size=128x128>,
#  'kyiv': <PIL.Image.Image image mode=RGB size=128x128>,
#  'zhaoqing': <PIL.Image.Image image mode=RGB size=128x128>}

# %%
images['beijing']
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
images_df = pd.DataFrame.from_dict(images, orient='index', columns=['image'])
images_df = images_df.reset_index().rename(columns={'index': 'name'})
images_df
# Out:
#                name                                              image
# 0    rio_de_janeiro  <PIL.Image.Image image mode=RGB size=128x128 a...
# 1          sao_luis  <PIL.Image.Image image mode=RGB size=128x128 a...
# 2          arequipa  <PIL.Image.Image image mode=RGB size=128x128 a...
# 3           posadas  <PIL.Image.Image image mode=RGB size=128x128 a...
# 4          zaragoza  <PIL.Image.Image image mode=RGB size=128x128 a...
# ..              ...                                                ...
# 939        changsha  <PIL.Image.Image image mode=RGB size=128x128 a...
# 940       monterrey  <PIL.Image.Image image mode=RGB size=128x128 a...
# 941          guntur  <PIL.Image.Image image mode=RGB size=128x128 a...
# 942            kyiv  <PIL.Image.Image image mode=RGB size=128x128 a...
# 943        zhaoqing  <PIL.Image.Image image mode=RGB size=128x128 a...
#
# [944 rows x 2 columns]

# %%
population = pd.read_csv(population_data_path)
population['name'] = population['name'].str.lower().str.replace(' ', '_')
population
# Out:
#                name       lon      lat  population
# 0          shanghai  121.4670  31.1667    22120000
# 1           beijing  116.3910  39.9050    19433000
# 2          shenzhen  114.0540  22.5350    15929000
# 3         guangzhou  113.2590  23.1288    20902000
# 4           chengdu  104.0670  30.6636    11309000
# ..              ...       ...      ...         ...
# 959           zadar   15.2167  44.1167       75082
# 960         nampula   39.2667 -15.1167      477900
# 961  slavonski_brod   18.0144  45.1553       56769
# 962        karlovac   15.5558  45.4931       53134
# 963         tbilisi   44.7925  41.7225     1118035
#
# [964 rows x 4 columns]

# %%
df = pd.merge(population, images_df, on='name', how='left')
df.dropna(inplace=True)
df
# Out:
#                name       lon      lat  population  \
# 0          shanghai  121.4670  31.1667    22120000
# 1           beijing  116.3910  39.9050    19433000
# 2          shenzhen  114.0540  22.5350    15929000
# 3         guangzhou  113.2590  23.1288    20902000
# 4           chengdu  104.0670  30.6636    11309000
# ..              ...       ...      ...         ...
# 959           zadar   15.2167  44.1167       75082
# 960         nampula   39.2667 -15.1167      477900
# 961  slavonski_brod   18.0144  45.1553       56769
# 962        karlovac   15.5558  45.4931       53134
# 963         tbilisi   44.7925  41.7225     1118035
#
#                                                  image
# 0    <PIL.Image.Image image mode=RGB size=128x128 a...
# 1    <PIL.Image.Image image mode=RGB size=128x128 a...
# 2    <PIL.Image.Image image mode=RGB size=128x128 a...
# 3    <PIL.Image.Image image mode=RGB size=128x128 a...
# 4    <PIL.Image.Image image mode=RGB size=128x128 a...
# ..                                                 ...
# 959  <PIL.Image.Image image mode=RGB size=128x128 a...
# 960  <PIL.Image.Image image mode=RGB size=128x128 a...
# 961  <PIL.Image.Image image mode=RGB size=128x128 a...
# 962  <PIL.Image.Image image mode=RGB size=128x128 a...
# 963  <PIL.Image.Image image mode=RGB size=128x128 a...
#
# [964 rows x 5 columns]

# %%
def transform_population(X):
    return np.log10(np.array(X)) * 1e-1

def detransform_population(X):
    return np.pow(10, np.array(X) * 1e1)

# %%
transform_population(detransform_population(3))
# Out:
# np.float64(3.0)

# %%
X = df['image'].to_list()
y = (df['population']).to_list()
y_transformed = transform_population(y)
y_transformed = y_transformed.tolist()

# %%
sns.kdeplot(y)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.kdeplot(y_transformed)
# Out:
# <Axes: ylabel='Density'>

# %%
class PILImageListValueDataset(Dataset):
    """
    Dataset class to load a list of PIL images and a corresponding list of values.
    """
    def __init__(self, image_list, target_values, transform=None):
        """
        Args:
            image_list (list): A list of PIL Image objects.
            target_values (list): A list of target values corresponding to each image.
                                  Ensure the length matches the image_list.
            transform (callable, optional): Optional transform to be applied
                on the image. Defaults to None.
        """
        if len(image_list) != len(target_values):
            raise ValueError("The length of image_list and target_values must be the same.")

        self.image_list = image_list
        self.target_values = target_values
        self.transform = transform

    def __len__(self):
        return len(self.image_list)

    def __getitem__(self, idx):
        image = self.image_list[idx]
        target_value = self.target_values[idx]

        if self.transform:
            image = self.transform(image)

        # Convert target_value to a PyTorch Tensor if it's not already
        if not isinstance(target_value, torch.Tensor):
            target_value = torch.tensor(target_value).float()  # Adjust dtype as needed

        return image, target_value

# %%
data_transform = transforms.Compose([
    transforms.ToTensor(),
])

dataset = PILImageListValueDataset(X, torch.Tensor(y_transformed).reshape(-1, 1), data_transform)
ratio = 0.8
train_len = int(len(dataset) * ratio)
test_len = len(dataset) - train_len
train_dataset, test_dataset = random_split(dataset, [train_len, test_len])

train_loader = DataLoader(
    train_dataset,
    32,
    True
)

len(train_dataset)
# Out:
# 771

# %%
class RelativeLoss(nn.Module):
    """
    Computes the Relative Loss (also known as Normalized Loss or Percentage Loss).

    The relative loss is defined as:
    (|target - prediction|) / (|target| + epsilon)

    where epsilon is a small constant to avoid division by zero when the target is zero.
    """
    def __init__(self, epsilon=1e-8):
        super(RelativeLoss, self).__init__()
        self.epsilon = epsilon

    def forward(self, prediction, target):
        """
        Args:
            prediction (torch.Tensor): The predicted values.
            target (torch.Tensor): The ground truth values.

        Returns:
            torch.Tensor: The computed relative loss.
        """
        numerator = torch.abs(target - prediction)
        denominator = torch.abs(target) + self.epsilon
        relative_loss = numerator / denominator
        return relative_loss.mean()

# %%
model = nn.Sequential(
    nn.Dropout2d(p=0.0),
    nn.Conv2d(3, 16, 3, 1, 'same'),
    nn.MaxPool2d(2, 2),
    nn.ReLU(),
    
    nn.Dropout2d(p=0.0),
    nn.Conv2d(16, 32, 3, 1, 'same'),
    nn.MaxPool2d(2, 2),
    nn.ReLU(),
    
    nn.Dropout2d(p=0.0),
    nn.Conv2d(32, 64, 3, 1, 'same'),
    nn.MaxPool2d(2, 2),
    nn.ReLU(),
    
    nn.Dropout2d(p=0.0),
    nn.Flatten(),
    nn.Linear(16384, 1)
)

y_loss = []
optim = torch.optim.Adam(model.parameters(), 1e-4)
criterion = nn.MSELoss()

# %%
dev = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(dev)
# Out:
# Sequential(
#   (0): Dropout2d(p=0.0, inplace=False)
#   (1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (3): ReLU()
#   (4): Dropout2d(p=0.0, inplace=False)
#   (5): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (7): ReLU()
#   (8): Dropout2d(p=0.0, inplace=False)
#   (9): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (11): ReLU()
#   (12): Dropout2d(p=0.0, inplace=False)
#   (13): Flatten(start_dim=1, end_dim=-1)
#   (14): Linear(in_features=16384, out_features=1, bias=True)
# )

# %%
epoch_n = 256

for epoch in range(epoch_n):
    # Set the model to training mode
    model.train()
    epoch_loss = 0.0
    num_batches = 0

    # Iterate over the batches in the DataLoader
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        # Move the input and target tensors to the device (e.g., GPU if available)
        if torch.cuda.is_available():
            inputs = inputs.cuda()
            targets = targets.cuda()
        
        # Forward pass
        predictions = model(inputs)

        # Calculate the loss
        loss = criterion(predictions, targets)

        # Backward pass and optimization
        optim.zero_grad()
        loss.backward()
        optim.step()

        # Record the loss for this batch
        epoch_loss += loss.item()
        num_batches += 1

        # Optional: Print batch-level loss
        # if batch_idx % 100 == 0:
        #     print(f"Epoch [{epoch+1}/{epoch_n}], Batch [{batch_idx+1}/{len(train_loader)}], Loss: {loss.item():.4f}")

    # Calculate the average loss for the epoch
    avg_epoch_loss = epoch_loss / num_batches
    y_loss.append(avg_epoch_loss)

    # Print the average loss for the epoch
    print(f"Epoch [{epoch+1}/{epoch_n}], Average Loss: {avg_epoch_loss:.4f}")
# Out:
# Epoch [1/256], Average Loss: 0.0456
# Epoch [2/256], Average Loss: 0.0064
# Epoch [3/256], Average Loss: 0.0049
# Epoch [4/256], Average Loss: 0.0047
# Epoch [5/256], Average Loss: 0.0048
# Epoch [6/256], Average Loss: 0.0047
# Epoch [7/256], Average Loss: 0.0045
# Epoch [8/256], Average Loss: 0.0049
# Epoch [9/256], Average Loss: 0.0046
# Epoch [10/256], Average Loss: 0.0046
# Epoch [11/256], Average Loss: 0.0046
# Epoch [12/256], Average Loss: 0.0043
# Epoch [13/256], Average Loss: 0.0043
# Epoch [14/256], Average Loss: 0.0041
# Epoch [15/256], Average Loss: 0.0043
# Epoch [16/256], Average Loss: 0.0038
# Epoch [17/256], Average Loss: 0.0040
# Epoch [18/256], Average Loss: 0.0041
# Epoch [19/256], Average Loss: 0.0040
# Epoch [20/256], Average Loss: 0.0037
# Epoch [21/256], Average Loss: 0.0038
# Epoch [22/256], Average Loss: 0.0034
# Epoch [23/256], Average Loss: 0.0036
# Epoch [24/256], Average Loss: 0.0038
# Epoch [25/256], Average Loss: 0.0035
# Epoch [26/256], Average Loss: 0.0033
# Epoch [27/256], Average Loss: 0.0034
# Epoch [28/256], Average Loss: 0.0032
# Epoch [29/256], Average Loss: 0.0034
# Epoch [30/256], Average Loss: 0.0031
# Epoch [31/256], Average Loss: 0.0031
# Epoch [32/256], Average Loss: 0.0030
# Epoch [33/256], Average Loss: 0.0031
# Epoch [34/256], Average Loss: 0.0031
# Epoch [35/256], Average Loss: 0.0028
# Epoch [36/256], Average Loss: 0.0027
# Epoch [37/256], Average Loss: 0.0029
# Epoch [38/256], Average Loss: 0.0026
# Epoch [39/256], Average Loss: 0.0026
# Epoch [40/256], Average Loss: 0.0029
# Epoch [41/256], Average Loss: 0.0026
# Epoch [42/256], Average Loss: 0.0025
# Epoch [43/256], Average Loss: 0.0025
# Epoch [44/256], Average Loss: 0.0022
# Epoch [45/256], Average Loss: 0.0024
# Epoch [46/256], Average Loss: 0.0022
# Epoch [47/256], Average Loss: 0.0022
# Epoch [48/256], Average Loss: 0.0023
# Epoch [49/256], Average Loss: 0.0022
# Epoch [50/256], Average Loss: 0.0021
# Epoch [51/256], Average Loss: 0.0022
# Epoch [52/256], Average Loss: 0.0020
# Epoch [53/256], Average Loss: 0.0021
# Epoch [54/256], Average Loss: 0.0020
# Epoch [55/256], Average Loss: 0.0019
# Epoch [56/256], Average Loss: 0.0019
# Epoch [57/256], Average Loss: 0.0021
# Epoch [58/256], Average Loss: 0.0019
# Epoch [59/256], Average Loss: 0.0017
# Epoch [60/256], Average Loss: 0.0017
# Epoch [61/256], Average Loss: 0.0017
# Epoch [62/256], Average Loss: 0.0016
# Epoch [63/256], Average Loss: 0.0015
# Epoch [64/256], Average Loss: 0.0016
# Epoch [65/256], Average Loss: 0.0015
# Epoch [66/256], Average Loss: 0.0014
# Epoch [67/256], Average Loss: 0.0014
# Epoch [68/256], Average Loss: 0.0014
# Epoch [69/256], Average Loss: 0.0012
# Epoch [70/256], Average Loss: 0.0014
# Epoch [71/256], Average Loss: 0.0014
# Epoch [72/256], Average Loss: 0.0012
# Epoch [73/256], Average Loss: 0.0011
# Epoch [74/256], Average Loss: 0.0013
# Epoch [75/256], Average Loss: 0.0013
# Epoch [76/256], Average Loss: 0.0013
# Epoch [77/256], Average Loss: 0.0010
# Epoch [78/256], Average Loss: 0.0009
# Epoch [79/256], Average Loss: 0.0009
# Epoch [80/256], Average Loss: 0.0009
# Epoch [81/256], Average Loss: 0.0009
# Epoch [82/256], Average Loss: 0.0008
# Epoch [83/256], Average Loss: 0.0008
# Epoch [84/256], Average Loss: 0.0009
# Epoch [85/256], Average Loss: 0.0009
# Epoch [86/256], Average Loss: 0.0008
# Epoch [87/256], Average Loss: 0.0007
# Epoch [88/256], Average Loss: 0.0006
# Epoch [89/256], Average Loss: 0.0007
# Epoch [90/256], Average Loss: 0.0007
# Epoch [91/256], Average Loss: 0.0009
# Epoch [92/256], Average Loss: 0.0008
# Epoch [93/256], Average Loss: 0.0006
# Epoch [94/256], Average Loss: 0.0006
# Epoch [95/256], Average Loss: 0.0006
# Epoch [96/256], Average Loss: 0.0005
# Epoch [97/256], Average Loss: 0.0007
# Epoch [98/256], Average Loss: 0.0006
# Epoch [99/256], Average Loss: 0.0005
# Epoch [100/256], Average Loss: 0.0005
# Epoch [101/256], Average Loss: 0.0004
# Epoch [102/256], Average Loss: 0.0005
# Epoch [103/256], Average Loss: 0.0006
# Epoch [104/256], Average Loss: 0.0004
# Epoch [105/256], Average Loss: 0.0004
# Epoch [106/256], Average Loss: 0.0004
# Epoch [107/256], Average Loss: 0.0004
# Epoch [108/256], Average Loss: 0.0003
# Epoch [109/256], Average Loss: 0.0003
# Epoch [110/256], Average Loss: 0.0003
# Epoch [111/256], Average Loss: 0.0004
# Epoch [112/256], Average Loss: 0.0003
# Epoch [113/256], Average Loss: 0.0003
# Epoch [114/256], Average Loss: 0.0003
# Epoch [115/256], Average Loss: 0.0003
# Epoch [116/256], Average Loss: 0.0002
# Epoch [117/256], Average Loss: 0.0002
# Epoch [118/256], Average Loss: 0.0002
# Epoch [119/256], Average Loss: 0.0002
# Epoch [120/256], Average Loss: 0.0002
# Epoch [121/256], Average Loss: 0.0002
# Epoch [122/256], Average Loss: 0.0002
# Epoch [123/256], Average Loss: 0.0002
# Epoch [124/256], Average Loss: 0.0002
# Epoch [125/256], Average Loss: 0.0002
# Epoch [126/256], Average Loss: 0.0002
# Epoch [127/256], Average Loss: 0.0001
# Epoch [128/256], Average Loss: 0.0001
# Epoch [129/256], Average Loss: 0.0001
# Epoch [130/256], Average Loss: 0.0001
# Epoch [131/256], Average Loss: 0.0001
# Epoch [132/256], Average Loss: 0.0001
# Epoch [133/256], Average Loss: 0.0002
# Epoch [134/256], Average Loss: 0.0002
# Epoch [135/256], Average Loss: 0.0001
# Epoch [136/256], Average Loss: 0.0001
# Epoch [137/256], Average Loss: 0.0001
# Epoch [138/256], Average Loss: 0.0001
# Epoch [139/256], Average Loss: 0.0001
# Epoch [140/256], Average Loss: 0.0001
# Epoch [141/256], Average Loss: 0.0001
# Epoch [142/256], Average Loss: 0.0001
# Epoch [143/256], Average Loss: 0.0003
# Epoch [144/256], Average Loss: 0.0001
# Epoch [145/256], Average Loss: 0.0001
# Epoch [146/256], Average Loss: 0.0001
# Epoch [147/256], Average Loss: 0.0001
# Epoch [148/256], Average Loss: 0.0001
# Epoch [149/256], Average Loss: 0.0001
# Epoch [150/256], Average Loss: 0.0001
# Epoch [151/256], Average Loss: 0.0001
# Epoch [152/256], Average Loss: 0.0000
# Epoch [153/256], Average Loss: 0.0000
# Epoch [154/256], Average Loss: 0.0001
# Epoch [155/256], Average Loss: 0.0000
# Epoch [156/256], Average Loss: 0.0000
# Epoch [157/256], Average Loss: 0.0001
# Epoch [158/256], Average Loss: 0.0001
# Epoch [159/256], Average Loss: 0.0000
# Epoch [160/256], Average Loss: 0.0000
# Epoch [161/256], Average Loss: 0.0000
# Epoch [162/256], Average Loss: 0.0000
# Epoch [163/256], Average Loss: 0.0001
# Epoch [164/256], Average Loss: 0.0000
# Epoch [165/256], Average Loss: 0.0000
# Epoch [166/256], Average Loss: 0.0000
# Epoch [167/256], Average Loss: 0.0000
# Epoch [168/256], Average Loss: 0.0000
# Epoch [169/256], Average Loss: 0.0000
# Epoch [170/256], Average Loss: 0.0000
# Epoch [171/256], Average Loss: 0.0000
# Epoch [172/256], Average Loss: 0.0000
# Epoch [173/256], Average Loss: 0.0001
# Epoch [174/256], Average Loss: 0.0000
# Epoch [175/256], Average Loss: 0.0000
# Epoch [176/256], Average Loss: 0.0000
# Epoch [177/256], Average Loss: 0.0000
# Epoch [178/256], Average Loss: 0.0000
# Epoch [179/256], Average Loss: 0.0000
# Epoch [180/256], Average Loss: 0.0000
# Epoch [181/256], Average Loss: 0.0000
# Epoch [182/256], Average Loss: 0.0000
# Epoch [183/256], Average Loss: 0.0000
# Epoch [184/256], Average Loss: 0.0000
# Epoch [185/256], Average Loss: 0.0000
# Epoch [186/256], Average Loss: 0.0000
# Epoch [187/256], Average Loss: 0.0000
# Epoch [188/256], Average Loss: 0.0000
# Epoch [189/256], Average Loss: 0.0000
# Epoch [190/256], Average Loss: 0.0000
# Epoch [191/256], Average Loss: 0.0000
# Epoch [192/256], Average Loss: 0.0000
# Epoch [193/256], Average Loss: 0.0000
# Epoch [194/256], Average Loss: 0.0000
# Epoch [195/256], Average Loss: 0.0000
# Epoch [196/256], Average Loss: 0.0000
# Epoch [197/256], Average Loss: 0.0000
# Epoch [198/256], Average Loss: 0.0000
# Epoch [199/256], Average Loss: 0.0000
# Epoch [200/256], Average Loss: 0.0000
# Epoch [201/256], Average Loss: 0.0000
# Epoch [202/256], Average Loss: 0.0000
# Epoch [203/256], Average Loss: 0.0000
# Epoch [204/256], Average Loss: 0.0000
# Epoch [205/256], Average Loss: 0.0000
# Epoch [206/256], Average Loss: 0.0000
# Epoch [207/256], Average Loss: 0.0000
# Epoch [208/256], Average Loss: 0.0000
# Epoch [209/256], Average Loss: 0.0000
# Epoch [210/256], Average Loss: 0.0000
# Epoch [211/256], Average Loss: 0.0000
# Epoch [212/256], Average Loss: 0.0000
# Epoch [213/256], Average Loss: 0.0000
# Epoch [214/256], Average Loss: 0.0000
# Epoch [215/256], Average Loss: 0.0000
# Epoch [216/256], Average Loss: 0.0000
# Epoch [217/256], Average Loss: 0.0000
# Epoch [218/256], Average Loss: 0.0000
# Epoch [219/256], Average Loss: 0.0000
# Epoch [220/256], Average Loss: 0.0000
# Epoch [221/256], Average Loss: 0.0000
# Epoch [222/256], Average Loss: 0.0000
# Epoch [223/256], Average Loss: 0.0000
# Epoch [224/256], Average Loss: 0.0000
# Epoch [225/256], Average Loss: 0.0000
# Epoch [226/256], Average Loss: 0.0000
# Epoch [227/256], Average Loss: 0.0000
# Epoch [228/256], Average Loss: 0.0000
# Epoch [229/256], Average Loss: 0.0000
# Epoch [230/256], Average Loss: 0.0000
# Epoch [231/256], Average Loss: 0.0000
# Epoch [232/256], Average Loss: 0.0000
# Epoch [233/256], Average Loss: 0.0000
# Epoch [234/256], Average Loss: 0.0000
# Epoch [235/256], Average Loss: 0.0000
# Epoch [236/256], Average Loss: 0.0000
# Epoch [237/256], Average Loss: 0.0000
# Epoch [238/256], Average Loss: 0.0000
# Epoch [239/256], Average Loss: 0.0000
# Epoch [240/256], Average Loss: 0.0000
# Epoch [241/256], Average Loss: 0.0000
# Epoch [242/256], Average Loss: 0.0000
# Epoch [243/256], Average Loss: 0.0000
# Epoch [244/256], Average Loss: 0.0000
# Epoch [245/256], Average Loss: 0.0000
# Epoch [246/256], Average Loss: 0.0000
# Epoch [247/256], Average Loss: 0.0000
# Epoch [248/256], Average Loss: 0.0001
# Epoch [249/256], Average Loss: 0.0001
# Epoch [250/256], Average Loss: 0.0000
# Epoch [251/256], Average Loss: 0.0000
# Epoch [252/256], Average Loss: 0.0000
# Epoch [253/256], Average Loss: 0.0000
# Epoch [254/256], Average Loss: 0.0000
# Epoch [255/256], Average Loss: 0.0000
# Epoch [256/256], Average Loss: 0.0000

# %%
plt.plot(y_loss)
plt.yscale('log')
plt.xscale('log')

# %%
model.eval()
# Out:
# Sequential(
#   (0): Dropout2d(p=0.0, inplace=False)
#   (1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (3): ReLU()
#   (4): Dropout2d(p=0.0, inplace=False)
#   (5): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (7): ReLU()
#   (8): Dropout2d(p=0.0, inplace=False)
#   (9): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (11): ReLU()
#   (12): Dropout2d(p=0.0, inplace=False)
#   (13): Flatten(start_dim=1, end_dim=-1)
#   (14): Linear(in_features=16384, out_features=1, bias=True)
# )

# %%
model.to('cpu')
a = 0

for (img, population) in test_dataset:
    prediction = model(img.unsqueeze(0))
    prediction = detransform_population(prediction.detach().numpy())
    true_population = detransform_population(population.detach().numpy())
    a += (np.abs(prediction - true_population)) / true_population
    
a /= len(test_dataset)
print(a)
# Out:
# [[4.2929673]]

# %%
a = 0

for (img, population) in train_dataset:
    prediction = model(img.unsqueeze(0))
    prediction = detransform_population(prediction.detach().numpy())
    true_population = detransform_population(population.detach().numpy())
    a += (np.abs(prediction - true_population)) / true_population
    
a /= len(train_dataset)
print(a)
# Out:
# [[0.07276982]]

# %%
img = train_dataset[5][0]
population = train_dataset[5][1]
prediction = model(img.unsqueeze(0))
prediction = detransform_population(prediction.detach().numpy())
population = detransform_population(population.detach().numpy())
relative_error = (np.abs(prediction - population)) / population
print(f'Population: {np.round(population.item())}\nprediction: {np.round(prediction.item())}\nrelacive error: {np.round(relative_error.item() * 100, 2)}%')
# Out:
# Population: 185103.0
# prediction: 203045.0
# relacive error: 9.69%

# %%
end_time = time.time()
execution_time = end_time - start_time
print(f"Total execution time: {execution_time:.2f} seconds")
# Out:
# Total execution time: 851.88 seconds
